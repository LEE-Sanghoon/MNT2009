# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)][def]
#
# [def]: https://colab.research.google.com/github/LEE-Sanghoon/MNT2009/blob/main/HandsOn-SVM.ipynb

# %% [markdown]
# # 서포트 벡터 머신
#
# **[참고]**
# [Hands-On Machine Learning](https://github.com/ExcelsiorCJH/Hands-On-ML/blob/master/Chap05-SVM/SVM-Summary.md)

# %% [markdown]
# ![](https://miro.medium.com/v2/resize:fit:1400/format:webp/1*ZDZcu5VdTGdl9-CguPLiSg.png)
