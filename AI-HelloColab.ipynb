# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/LEE-Sanghoon/MNT2009/blob/main/HelloColab.ipynb)

# %% [markdown]
# # 인공지능의이해
# ## 파이썬 프로그래밍 실습환경 연습

# %%
print("Hello, Colab")
# Out:
# Hello, Colab

# %%
import time

start = time.time()
sum = 0
for i in range(1, 10000001):
  sum = sum + i

end = time.time()

print('1+2+...+10000001=', sum)
print('소요시간은 ', end-start, '초 입니다')

# %% [markdown]
# 터틀 그래픽스

# %%
# !pip install ColabTurtle

# %%
from ColabTurtle import Turtle as turtle

turtle.initializeTurtle()
turtle.shape("turtle")

turtle.forward(50)
turtle.left(90)
turtle.forward(60)
turtle.left(100)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="200.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="200.0" x2="340.0" y2="200.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#         <g visibility=visible transform="rotate(170,340.0,200.0) translate(322.0, 182.0)">
# ...

# %%
# !pip3 install gTTS

# %%
from gtts import gTTS

text_to_say = "안녕하세요. 인공지능 수업입니다."
language = "ko"

gtts_object = gTTS(text = text_to_say,
                   lang = language,
                   slow = False)

gtts_object.save('/content/gtts.wav')

# %%
from IPython.display import Audio
Audio('/content/gtts.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
